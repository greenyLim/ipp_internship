# %%
import pandas as pd

# %%
df=pd.read_csv('최종1.csv')
df
# Out:
#       회원아이디        이름                        이메일  핸드폰  팩스  고객정보1  고객정보2  \
# 0       NaN       이충석       oltkorea@hanmail.net  NaN NaN  예비창업자    NaN
# 1       NaN       이택진    taekjinnashyi@gmail.com  NaN NaN   게임마루    NaN
# 2       NaN       이혜미        wushu0829@naver.com  NaN NaN     에떼    NaN
# 3       NaN       임완수         wslim888@gmail.com  NaN NaN  예비창업자    NaN
# 4       NaN       정대휘          iaminn8@naver.com  NaN NaN   트라이탭    NaN
# ...     ...       ...                        ...  ...  ..    ...    ...
# 3056    NaN       위커버      manager@wecoverai.com  NaN NaN    NaN    NaN
# 3057    NaN      위클립스  support@dealingroom.co.kr  NaN NaN    NaN    NaN
# 3058    NaN    케이알지그룹     support@krggroup.co.kr  NaN NaN    NaN    NaN
# 3059    NaN  에이블테라퓨틱스           info@aible.co.kr  NaN NaN    NaN    NaN
# 3060    NaN    원더풀플랫폼         sales@1thefull.com  NaN NaN    NaN    NaN
#
#       고객정보3  고객정보4  고객정보5 이메일수신거부여부  이메일수신거부시각 문자수신거부여부  문자수신거부시각
# ...

# %%
df1=df.drop_duplicates(subset=['이메일'], keep='first').reset_index(drop=True)
df1
# Out:
#       회원아이디        이름                        이메일  핸드폰  팩스  고객정보1  고객정보2  \
# 0       NaN       이충석       oltkorea@hanmail.net  NaN NaN  예비창업자    NaN
# 1       NaN       이택진    taekjinnashyi@gmail.com  NaN NaN   게임마루    NaN
# 2       NaN       이혜미        wushu0829@naver.com  NaN NaN     에떼    NaN
# 3       NaN       임완수         wslim888@gmail.com  NaN NaN  예비창업자    NaN
# 4       NaN       정대휘          iaminn8@naver.com  NaN NaN   트라이탭    NaN
# ...     ...       ...                        ...  ...  ..    ...    ...
# 2909    NaN      페어랩스           team@fairlabs.io  NaN NaN    NaN    NaN
# 2910    NaN      위클립스  support@dealingroom.co.kr  NaN NaN    NaN    NaN
# 2911    NaN    케이알지그룹     support@krggroup.co.kr  NaN NaN    NaN    NaN
# 2912    NaN  에이블테라퓨틱스           info@aible.co.kr  NaN NaN    NaN    NaN
# 2913    NaN    원더풀플랫폼         sales@1thefull.com  NaN NaN    NaN    NaN
#
#       고객정보3  고객정보4  고객정보5 이메일수신거부여부  이메일수신거부시각 문자수신거부여부  문자수신거부시각
# ...

# %%
final = df1[df1['고객정보1'] != '예비창업자']

# %%
final.to_csv('사업홍보리스트.csv',index=False, encoding='utf-8-sig')
